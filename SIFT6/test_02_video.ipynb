# %%
import cv2 as cv
from multiprocessing import Pool, cpu_count
from time import time
from stitching import Stitcher

# 封装图像拼接函数
def stitch_images_from_videos(video_paths, frame_index, settings, settings1):
    # 使用 settings 进行初步拼接
    stitcher = Stitcher(**settings)
    panoramas = []
    images = []
    for video_path in video_paths:
        cap = cv.VideoCapture(video_path)
        cap.set(cv.CAP_PROP_POS_FRAMES, frame_index)
        ret, frame = cap.read()
        if not ret:
            raise ValueError(f"Could not read frame {frame_index} from video {video_path}")
        images.append(frame)
        cap.release()
    
    # 进行初步拼接
    panorama0 = stitcher.stitch([images[0], images[1]])
    panorama1 = stitcher.stitch([images[2], images[3]])
    
    # 使用 settings1 进行最终拼接
    stitcher1 = Stitcher(**settings1)
    final_panorama = stitcher1.stitch([panorama0, panorama1])
    return final_panorama

# 多进程处理函数
def multiprocess_stitch(video_path_groups, frame_indices, settings, settings1, num_processes):
    with Pool(num_processes) as pool:
        args = [(group, frame_index, settings, settings1) for group, frame_index in zip(video_path_groups, frame_indices)]
        panoramas = pool.starmap(stitch_images_from_videos, args)
    return panoramas

# if __name__ == "__main__":
#     # 定义视频路径组
#     video_paths = ["../data/testolabc1.avi", "../data/testolabc2.avi", "../data/testolabc3.avi", "../data/testolabc4.avi"]
    
#     # 假设我们要处理前8帧，每帧组成一组
#     num_frames = 16
#     video_path_groups = [video_paths for _ in range(num_frames)]
#     frame_indices = list(range(num_frames))

#     # 设置参数
#     settings = {"detector": "orb", "range_width": 600, "confidence_threshold": 0.01, "print_time": False, "crop": False}
#     settings1 = {"detector": "sift", "range_width": 900, "confidence_threshold": 0.01, "print_time": False, "crop": False}

#     # 测试性能
#     num_processes = max(8, cpu_count())  # 使用最多8个进程

#     start_time = time()
#     panoramas = multiprocess_stitch(video_path_groups, frame_indices, settings, settings1, num_processes)
    
#     # 保存最终拼接图像
#     for idx, panorama in enumerate(panoramas):
#         cv.imwrite(f"./output/panoramav_{idx}.jpg", panorama)
    
#     end_time = time()

#     print(f"Total stitching time with {num_processes} processes: {end_time - start_time:.4f} seconds")
#     print(f"fps : {num_frames / (end_time-start_time):.3f} ")

# %%
from multiprocessing import Pool, TimeoutError
import signal

# 设置超时信号处理
def init_worker():
    signal.signal(signal.SIGINT, signal.SIG_IGN)

def multiprocess_stitch(video_path_groups, frame_indices, settings, settings1, num_processes):
    with Pool(num_processes, initializer=init_worker) as pool:
        try:
            args = [(group, frame_index, settings, settings1) for group, frame_index in zip(video_path_groups, frame_indices)]
            results = pool.starmap_async(stitch_images_from_videos, args)
            panoramas = results.get(timeout=600)  # 设置超时时间为600秒
            return panoramas
        except TimeoutError:
            print("Stitching process timed out.")
            pool.terminate()
            pool.join()
            return []
if __name__ == "__main__":
    # 定义视频路径组
    video_paths = ["../data/testolabc1.avi", "../data/testolabc2.avi", "../data/testolabc3.avi", "../data/testolabc4.avi"]
    
    # 假设我们要处理前16帧，每帧组成一组
    num_frames = 16
    video_path_groups = [video_paths for _ in range(num_frames)]
    frame_indices = list(range(num_frames))

    # 设置参数
    settings = {
        "detector": "orb", "range_width": 600, "confidence_threshold": 0.01, 
        "print_time": False, "crop": False, "use_momentum": True, "momentum_interval": 5
    }
    settings1 = {
        "detector": "sift", "range_width": 900, "confidence_threshold": 0.01, 
        "print_time": False, "crop": False, "use_momentum": True, "momentum_interval": 5
    }

    # 测试性能
    num_processes = min(8, cpu_count())  # 使用最多8个进程

    start_time = time.time()
    print(f"Starting stitching with {num_processes} processes")
    panoramas = multiprocess_stitch(video_path_groups, frame_indices, settings, settings1, num_processes)
    
    # 保存最终拼接图像
    for idx, panorama in enumerate(panoramas):
        cv.imwrite(f"./output/panoramav_{idx}.jpg", panorama)
        print(f"Saved panorama {idx}")
    
    end_time = time.time()

    print(f"Total stitching time with {num_processes} processes: {end_time - start_time:.4f} seconds")
    print(f"fps : {num_frames / (end_time - start_time):.3f}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 42
#      39 # 测试性能
#      40 num_processes = min(8, cpu_count())  # 使用最多8个进程
# ---> 42 start_time = time.time()
#      43 print(f"Starting stitching with {num_processes} processes")
#      44 panoramas = multiprocess_stitch(video_path_groups, frame_indices, settings, settings1, num_processes)
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'time'

# %%
import cv2 as cv
from multiprocessing import Pool, cpu_count, TimeoutError
from time import time
import signal
from stitching import Stitcher # type: ignore

# 封装图像拼接函数
def stitch_images_from_videos(video_paths, frame_index, settings, settings1):
    try:
        # 使用 settings 进行初步拼接
        stitcher = Stitcher(**settings)
        panoramas = []
        images = []
        for video_path in video_paths:
            cap = cv.VideoCapture(video_path)
            cap.set(cv.CAP_PROP_POS_FRAMES, frame_index)
            ret, frame = cap.read()
            if not ret:
                raise ValueError(f"Could not read frame {frame_index} from video {video_path}")
            images.append(frame)
            cap.release()

        # 进行初步拼接
        panorama0 = stitcher.stitch([images[0], images[1]])
        panorama1 = stitcher.stitch([images[2], images[3]])

        # 使用 settings1 进行最终拼接
        stitcher1 = Stitcher(**settings1)
        final_panorama = stitcher1.stitch([panorama0, panorama1])
        return final_panorama
    except Exception as e:
        print(f"Error during stitching frame {frame_index}: {e}")
        return None

# 设置超时信号处理
def init_worker():
    signal.signal(signal.SIGINT, signal.SIG_IGN)

# 多进程处理函数
def multiprocess_stitch(video_path_groups, frame_indices, settings, settings1, num_processes):
    with Pool(num_processes, initializer=init_worker) as pool:
        try:
            args = [(group, frame_index, settings, settings1) for group, frame_index in zip(video_path_groups, frame_indices)]
            results = pool.starmap_async(stitch_images_from_videos, args)
            panoramas = results.get(timeout=500)  # 设置超时时间为600秒
            return panoramas
        except TimeoutError:
            print("Stitching process timed out.")
            pool.terminate()
            pool.join()
            return []

if __name__ == "__main__":
    # 定义视频路径组
    video_paths = ["../data/testolabc1.avi", "../data/testolabc2.avi", "../data/testolabc3.avi", "../data/testolabc4.avi"]
    
    # 假设我们要处理前16帧，每帧组成一组
    num_frames = 256
    video_path_groups = [video_paths for _ in range(num_frames)]
    frame_indices = list(range(num_frames))

    # 设置参数
    settings = {
        "detector": "orb", "range_width": 600, "confidence_threshold": 0.01, 
        "print_time": True, "crop": False, "use_momentum": True, "momentum_interval": 10
    }
    settings1 = {
        "detector": "sift", "range_width": 900, "confidence_threshold": 0.01, 
        "print_time": False, "crop": False, "use_momentum": True, "momentum_interval": 10
    }

    # 测试性能
    num_processes = min(8, cpu_count())  # 使用最多8个进程

    start_time = time()
    print(f"Starting stitching with {num_processes} processes")
    panoramas = multiprocess_stitch(video_path_groups, frame_indices, settings, settings1, num_processes)
    
    # 保存最终拼接图像
    for idx, panorama in enumerate(panoramas):
        if panorama is not None:
            cv.imwrite(f"./output/panoramav_{idx}.jpg", panorama)
            print(f"Saved panorama {idx}")
    
    end_time = time()

    print(f"Total stitching time with {num_processes} processes: {end_time - start_time:.4f} seconds")
    print(f"fps : {num_frames / (end_time - start_time):.3f}")
# Out:
# Starting stitching with 8 processes
# Stitching call count: 1
# Stitching call count: 1Function resize_medium_resolution took 0.0003 seconds
#
# Stitching call count: 1Function resize_medium_resolution took 0.0004 seconds
#
# Function resize_medium_resolution took 0.0003 seconds
# Stitching call count: 1
# Stitching call count: 1Stitching call count: 1Function resize_medium_resolution took 0.0003 seconds
#
#
# Function resize_medium_resolution took 0.0006 secondsFunction resize_medium_resolution took 0.0007 seconds
#
# Stitching call count: 1Function find_features took 0.0223 secondsFunction find_features took 0.0173 seconds
#
#
# Function find_features took 0.0215 seconds
# Function resize_medium_resolution took 0.0002 seconds
# Stitching call count: 1
# Function resize_medium_resolution took 0.0003 secondsFunction find_features took 0.0194 seconds
# Function find_features took 0.0142 seconds
#
# Function find_features took 0.0173 seconds
# Function find_features took 0.0187 seconds
# Function match_features took 0.0215 secondsFunction match_features took 0.0256 seconds
# Function find_features took 0.0148 seconds
#
# Function match_features took 0.0251 secondsFunction subset took 0.0003 secondsFunction subset took 0.0003 seconds
#
#
# Function estimate_camera_parameters took 0.0001 secondsFunction subset took 0.0005 secondsFunction estimate_camera_parameters took 0.0002 seconds
#
#
# Function match_features took 0.0187 secondsEstimated camera parametersEstimated camera parametersFunction estimate_camera_parameters took 0.0001 seconds
#
#
#
# Estimated camera parametersFunction subset took 0.0003 secondsUpdated camera parameters with momentum
# Updated camera parameters with momentum
#
#
# Updated camera parameters with momentumFunction estimate_camera_parameters took 0.0002 seconds
# Function match_features took 0.0183 secondsFunction match_features took 0.0200 secondsFunction refine_camera_parameters took 0.0014 seconds
#
#
#
# Estimated camera parameters
# Function subset took 0.0003 seconds(< cv2.detail.CameraParams 0x77b97161ce40>, < cv2.detail.CameraParams 0x77b96b4b7030>)Function subset took 0.0003 seconds
#
# Updated camera parameters with momentumFunction refine_camera_parameters took 0.0024 seconds
# Function perform_wave_correction took 0.0001 seconds
#
#
# Function estimate_camera_parameters took 0.0001 secondsFunction estimate_camera_parameters took 0.0003 seconds
# Function estimate_scale took 0.0000 seconds(< cv2.detail.CameraParams 0x77b97161ce40>, < cv2.detail.CameraParams 0x77b96b4b9030>)
# Estimated camera parameters
#
# Estimated camera parameters
#
# Updated camera parameters with momentumFunction resize_low_resolution took 0.0011 secondsFunction perform_wave_correction took 0.0003 secondsUpdated camera parameters with momentumFunction refine_camera_parameters took 0.0030 seconds
#
#
# Function match_features took 0.0181 seconds
# Function warp took 0.0002 seconds
#
# Function estimate_scale took 0.0000 seconds
# Function subset took 0.0003 seconds(< cv2.detail.CameraParams 0x77b97161ce40>, < cv2.detail.CameraParams 0x77b96b4b9030>)
#
# Function refine_camera_parameters took 0.0145 seconds
#
# Function perform_wave_correction took 0.0001 seconds
# (< cv2.detail.CameraParams 0x77b97161ce40>, < cv2.detail.CameraParams 0x77b96b4b7030>)Function refine_camera_parameters took 0.0042 secondsFunction estimate_camera_parameters took 0.0001 secondsFunction resize_low_resolution took 0.0011 secondsFunction estimate_scale took 0.0000 seconds
#
#
#
#
# Function perform_wave_correction took 0.0001 secondsEstimated camera parametersFunction warp took 0.0002 seconds(< cv2.detail.CameraParams 0x77b97161ce40>, < cv2.detail.CameraParams 0x77b96b4b7030>)
# Function resize_low_resolution took 0.0009 seconds
# Function estimate_scale took 0.0000 seconds
# Function perform_wave_correction took 0.0001 seconds
# Function warp took 0.0002 seconds
#
# Function match_features took 0.0303 secondsFunction refine_camera_parameters took 0.0096 seconds
# Updated camera parameters with momentum
#
#
#
# Function resize_low_resolution took 0.0009 seconds(< cv2.detail.CameraParams 0x77b97161ce40>, < cv2.detail.CameraParams 0x77b96b4b9030>)
# Function estimate_scale took 0.0000 secondsFunction subset took 0.0003 secondsFunction warp took 0.0003 seconds
# Function warp_low_resolution took 0.0144 seconds
#
# Function perform_wave_correction took 0.0001 seconds
#
#
# Function estimate_scale took 0.0001 secondsFunction estimate_camera_parameters took 0.0001 secondsFunction prepare_cropper took 0.0000 seconds
#
# Function resize_low_resolution took 0.0016 seconds
# Estimated camera parametersFunction crop took 0.0000 secondsFunction resize_low_resolution took 0.0011 seconds
#
#
# Function crop_low_resolution took 0.0020 secondsFunction warp took 0.0002 secondsUpdated camera parameters with momentum
# Function warp_low_resolution took 0.0133 seconds
#
#
# Function warp took 0.0002 secondsFunction warp_low_resolution took 0.0122 seconds
# Function prepare_cropper took 0.0000 seconds
#
#
# Function crop took 0.0000 secondsFunction prepare_cropper took 0.0000 secondsFunction warp_low_resolution took 0.0108 seconds
#
#
# Function refine_camera_parameters took 0.0033 secondsFunction crop_low_resolution took 0.0016 secondsFunction prepare_cropper took 0.0000 secondsFunction crop took 0.0000 seconds
#
#
# (< cv2.detail.CameraParams 0x77b97161ce40>, < cv2.detail.CameraParams 0x77b96b4b9030>)
# Function crop_low_resolution took 0.0015 secondsFunction crop took 0.0000 seconds
# Function refine_camera_parameters took 0.0160 seconds
# Function find_seam_masks took 0.0060 secondsFunction perform_wave_correction took 0.0002 seconds
#
#
# (< cv2.detail.CameraParams 0x77b97161ce40>, < cv2.detail.CameraParams 0x77b96b4b7030>)
# Function resize_final_resolution took 0.0000 secondsFunction crop_low_resolution took 0.0034 seconds
#
# Function estimate_scale took 0.0000 seconds
# Function perform_wave_correction took 0.0001 seconds
# Function warp took 0.0002 seconds
# Function warp_low_resolution took 0.0128 seconds
# Function find_seam_masks took 0.0067 secondsFunction resize_low_resolution took 0.0013 secondsFunction warp_low_resolution took 0.0120 secondsFunction estimate_scale took 0.0000 seconds
# Function warp_final_resolution took 0.0031 seconds
#
# Function find_seam_masks took 0.0052 seconds
#
#
# Function resize_final_resolution took 0.0000 secondsFunction prepare_cropper took 0.0000 seconds
# Function prepare_cropper took 0.0000 secondsFunction crop took 0.0000 seconds
#
# Function warp took 0.0002 secondsFunction resize_final_resolution took 0.0000 seconds
#
# Function resize_low_resolution took 0.0010 secondsFunction crop took 0.0000 seconds
#
# Function warp took 0.0003 seconds
# Function crop_final_resolution took 0.0018 secondsFunction crop took 0.0000 seconds
#
#
# Function warp took 0.0002 seconds
# Function crop_low_resolution took 0.0020 secondsFunction crop_low_resolution took 0.0023 secondsFunction find_seam_masks took 0.0066 secondsFunction warp_final_resolution took 0.0029 secondsFunction resize_seam_masks took 0.0000 secondsFunction warp took 0.0003 seconds
#
#
#
#
#
# Function resize_final_resolution took 0.0000 secondsFunction warp_final_resolution took 0.0023 seconds
# Function crop took 0.0000 seconds
#
#
# Function crop took 0.0000 secondsFunction initialize_composition took 0.0009 secondsFunction crop_final_resolution took 0.0026 seconds
#
# Function warp took 0.0003 seconds
# Function resize_seam_masks took 0.0000 secondsFunction warp_low_resolution took 0.0102 seconds
# Function crop_final_resolution took 0.0025 seconds
# Function warp_final_resolution took 0.0018 seconds
# Function find_seam_masks took 0.0056 seconds
#
# Function find_seam_masks took 0.0069 secondsFunction prepare_cropper took 0.0000 secondsFunction initialize_composition took 0.0006 secondsFunction crop took 0.0000 secondsFunction resize_seam_masks took 0.0000 seconds
#
#
# Function resize_final_resolution took 0.0000 seconds
#
# Function crop_final_resolution took 0.0015 secondsFunction crop took 0.0000 seconds
#
# Function warp_low_resolution took 0.0116 seconds
#
# Function warp took 0.0003 seconds
# Function resize_final_resolution took 0.0000 secondsFunction initialize_composition took 0.0008 secondsFunction crop_low_resolution took 0.0020 seconds
#
# Function resize_seam_masks took 0.0000 seconds
# Function prepare_cropper took 0.0000 seconds
# Function warp_final_resolution took 0.0035 secondsFunction warp took 0.0003 seconds
#
# Function crop took 0.0000 secondsFunction initialize_composition took 0.0009 seconds
#
#
#
# Function crop_low_resolution took 0.0026 secondsFunction warp_final_resolution took 0.0040 secondsFunction crop took 0.0000 secondsFunction find_seam_masks took 0.0044 seconds
#
#
#
# Function crop_final_resolution took 0.0027 secondsFunction crop took 0.0000 secondsFunction resize_final_resolution took 0.0000 seconds
#
#
# Function resize_seam_masks took 0.0000 secondsFunction crop_final_resolution took 0.0030 seconds
# Function warp took 0.0003 seconds
#
# Function find_seam_masks took 0.0058 secondsFunction initialize_composition took 0.0007 secondsFunction resize_seam_masks took 0.0000 secondsFunction warp_final_resolution took 0.0042 seconds
#
#
#
# Function resize_final_resolution took 0.0000 secondsFunction crop took 0.0000 seconds
#
# Function initialize_composition took 0.0009 secondsFunction crop_final_resolution took 0.0027 secondsFunction warp took 0.0003 seconds
#
# Function warp_final_resolution took 0.0033 seconds
#
# Function resize_seam_masks took 0.0000 secondsFunction crop took 0.0000 seconds
#
# Function initialize_composition took 0.0012 secondsFunction crop_final_resolution took 0.0055 seconds
#
# Function resize_seam_masks took 0.0000 seconds
# Function initialize_composition took 0.0006 secondsFunction blend_images took 0.0598 seconds
#
# Function blend_images took 0.0660 seconds
# Function create_final_panorama took 0.0131 secondsFunction blend_images took 0.0771 secondsFunction blend_images took 0.0700 seconds
#
#
# Stitching call count: 2
# Function create_final_panorama took 0.0081 secondsFunction resize_medium_resolution took 0.0004 secondsFunction create_final_panorama took 0.0070 seconds
#
# Function create_final_panorama took 0.0074 seconds
#
# Stitching call count: 2Stitching call count: 2
#
# Stitching call count: 2
# Function resize_medium_resolution took 0.0002 secondsFunction resize_medium_resolution took 0.0002 secondsFunction blend_images took 0.0822 secondsFunction resize_medium_resolution took 0.0010 seconds
#
# Function blend_images took 0.0641 seconds
#
#
# Function find_features took 0.0246 seconds
# Function create_final_panorama took 0.0089 seconds
# Function find_features took 0.0151 secondsStitching call count: 2
#
# Function resize_medium_resolution took 0.0002 secondsFunction create_final_panorama took 0.0139 secondsFunction find_features took 0.0127 seconds
#
#
# Function find_features took 0.0179 seconds
# Stitching call count: 2
# Function blend_images took 0.1071 secondsFunction resize_medium_resolution took 0.0002 seconds
#
# Function find_features took 0.0135 seconds
# Function match_features took 0.0223 secondsFunction match_features took 0.0222 seconds
# Function blend_images took 0.0892 secondsFunction create_final_panorama took 0.0080 seconds
# Function subset took 0.0002 seconds
#
# Function subset took 0.0001 seconds
# Stitching call count: 2Used previous camera parameters
# Function find_features took 0.0105 seconds
#
# Used previous camera parametersFunction resize_medium_resolution took 0.0002 seconds
#
#
# Function match_features took 0.0245 seconds
# Function subset took 0.0002 secondsFunction create_final_panorama took 0.0065 seconds
# Function match_features took 0.0298 seconds
#
# Used previous camera parametersStitching call count: 2
# Function subset took 0.0001 seconds
# Function resize_medium_resolution took 0.0002 seconds
#
# Used previous camera parameters
# Function match_features took 0.0223 secondsFunction find_features took 0.0121 seconds
#
# Function subset took 0.0002 secondsFunction match_features took 0.0166 seconds
# Used previous camera parameters
# Function subset took 0.0001 seconds
#
# Function find_features took 0.0115 secondsUsed previous camera parameters
#
# Function match_features took 0.0145 seconds
# Function subset took 0.0002 seconds
# Used previous camera parameters
# Function match_features took 0.0203 seconds
# Function subset took 0.0002 seconds
# Used previous camera parameters
# Function refine_camera_parameters took 0.0870 seconds
# (< cv2.detail.CameraParams 0x77b96b4b7120>, < cv2.detail.CameraParams 0x77b96b4b7210>)
# Function perform_wave_correction took 0.0001 seconds
# Function estimate_scale took 0.0000 seconds
# Function refine_camera_parameters took 0.0830 secondsFunction resize_low_resolution took 0.0009 seconds
#
# (< cv2.detail.CameraParams 0x77b96b4b9120>, < cv2.detail.CameraParams 0x77b96b4b9210>)Function warp took 0.0001 seconds
#
# Function perform_wave_correction took 0.0001 seconds
# Function estimate_scale took 0.0000 seconds
# Function refine_camera_parameters took 0.0855 secondsFunction resize_low_resolution took 0.0011 seconds
#
# (< cv2.detail.CameraParams 0x77b96b4b7120>, < cv2.detail.CameraParams 0x77b96b4b7210>)Function warp took 0.0001 secondsFunction refine_camera_parameters took 0.0951 seconds
#
#
# Function perform_wave_correction took 0.0001 seconds(< cv2.detail.CameraParams 0x77b96b4b9120>, < cv2.detail.CameraParams 0x77b96b4b9210>)
#
# Function estimate_scale took 0.0000 seconds
# Function perform_wave_correction took 0.0001 secondsFunction refine_camera_parameters took 0.0782 seconds
#
# Function resize_low_resolution took 0.0014 secondsFunction estimate_scale took 0.0000 seconds
# (< cv2.detail.CameraParams 0x77b96b4b7120>, < cv2.detail.CameraParams 0x77b96b4b7210>)
# Function warp took 0.0002 seconds
# Function warp_low_resolution took 0.0115 seconds
# Function resize_low_resolution took 0.0009 secondsFunction perform_wave_correction took 0.0001 seconds
#
#
# Function prepare_cropper took 0.0000 secondsFunction warp took 0.0001 secondsFunction estimate_scale took 0.0000 seconds
#
#
# Function crop took 0.0000 seconds
# Function resize_low_resolution took 0.0008 secondsFunction crop_low_resolution took 0.0013 seconds
#
# Function warp_low_resolution took 0.0135 secondsFunction warp took 0.0002 seconds
#
# Function prepare_cropper took 0.0000 secondsFunction refine_camera_parameters took 0.0935 seconds
#
# Function crop took 0.0000 seconds(< cv2.detail.CameraParams 0x77b96b4b9120>, < cv2.detail.CameraParams 0x77b96b4b9210>)
#
# Function crop_low_resolution took 0.0023 secondsFunction perform_wave_correction took 0.0001 secondsFunction refine_camera_parameters took 0.0789 seconds
# Function find_seam_masks took 0.0060 secondsFunction warp_low_resolution took 0.0130 seconds
#
# Function estimate_scale took 0.0000 seconds
#
#
# Function resize_final_resolution took 0.0000 seconds(< cv2.detail.CameraParams 0x77b96b4b9120>, < cv2.detail.CameraParams 0x77b96b4b9210>)Function prepare_cropper took 0.0000 seconds
#
#
# Function warp_low_resolution took 0.0131 secondsFunction crop took 0.0000 secondsFunction warp took 0.0002 secondsFunction perform_wave_correction took 0.0001 seconds
#
#
# Function resize_low_resolution took 0.0019 secondsFunction prepare_cropper took 0.0000 secondsFunction warp_final_resolution took 0.0015 seconds
# Function estimate_scale took 0.0000 secondsFunction warp took 0.0001 seconds
#
#
# Function find_seam_masks took 0.0062 secondsFunction crop took 0.0000 seconds
# Function crop took 0.0000 seconds
#
# Function resize_low_resolution took 0.0008 seconds
# Function crop_low_resolution took 0.0040 seconds
# Function crop_final_resolution took 0.0015 secondsFunction warp_low_resolution took 0.0146 seconds
# Function crop_low_resolution took 0.0012 seconds
#
#
# Function resize_final_resolution took 0.0000 seconds
# Function warp took 0.0002 secondsFunction prepare_cropper took 0.0000 secondsFunction refine_camera_parameters took 0.0814 seconds
#
#
#
# Function crop took 0.0000 secondsFunction warp took 0.0004 secondsFunction resize_seam_masks took 0.0000 seconds
# (< cv2.detail.CameraParams 0x77b96b4b7120>, < cv2.detail.CameraParams 0x77b96b4b7210>)
#
# Function warp_final_resolution took 0.0024 seconds
#
# Function initialize_composition took 0.0009 secondsFunction find_seam_masks took 0.0068 secondsFunction perform_wave_correction took 0.0001 secondsFunction find_seam_masks took 0.0064 secondsFunction crop_low_resolution took 0.0048 seconds
#
# Function crop took 0.0000 secondsFunction resize_final_resolution took 0.0000 seconds
#
# Function resize_final_resolution took 0.0000 seconds
#
# Function warp_low_resolution took 0.0136 seconds
# Function estimate_scale took 0.0000 secondsFunction crop_final_resolution took 0.0043 seconds
# Function warp took 0.0002 seconds
#
#
# Function warp took 0.0003 seconds
# Function resize_seam_masks took 0.0000 seconds
# Function warp_final_resolution took 0.0043 secondsFunction resize_low_resolution took 0.0012 seconds
# Function prepare_cropper took 0.0000 seconds
# Function warp_final_resolution took 0.0021 seconds
#
# Function initialize_composition took 0.0007 secondsFunction warp took 0.0002 secondsFunction find_seam_masks took 0.0073 seconds
#
# Function warp_low_resolution took 0.0174 secondsFunction crop took 0.0000 seconds
#
# Function crop took 0.0000 seconds
#
# Function prepare_cropper took 0.0000 secondsFunction crop_final_resolution took 0.0022 secondsFunction crop took 0.0000 seconds
#
# Function resize_final_resolution took 0.0000 seconds
# Function crop_final_resolution took 0.0026 seconds
# Function resize_seam_masks took 0.0000 secondsFunction crop took 0.0000 seconds
#
#
# Function resize_seam_masks took 0.0000 seconds
# Function crop_low_resolution took 0.0024 seconds
# Function warp took 0.0003 secondsFunction crop_low_resolution took 0.0060 seconds
#
# Function warp_final_resolution took 0.0041 seconds
#
# Function initialize_composition took 0.0037 secondsFunction warp_low_resolution took 0.0153 secondsFunction crop took 0.0000 seconds
#
# Function find_seam_masks took 0.0070 secondsFunction initialize_composition took 0.0034 seconds
# Function prepare_cropper took 0.0000 secondsFunction find_seam_masks took 0.0105 seconds
# Function crop took 0.0000 seconds
#
# Function crop_final_resolution took 0.0070 seconds
# Function resize_final_resolution took 0.0000 seconds
# Function resize_final_resolution took 0.0000 seconds
#
# Function crop_low_resolution took 0.0063 seconds
# Function warp took 0.0003 seconds
# Function warp took 0.0002 secondsFunction warp_final_resolution took 0.0030 seconds
#
#
# Function warp_final_resolution took 0.0046 secondsFunction crop took 0.0000 seconds
#
# Function resize_seam_masks took 0.0000 secondsFunction crop took 0.0000 seconds
#
# Function initialize_composition took 0.0012 secondsFunction crop_final_resolution took 0.0054 secondsFunction crop_final_resolution took 0.0041 seconds
#
# Function resize_seam_masks took 0.0000 seconds
# Function resize_seam_masks took 0.0000 secondsFunction find_seam_masks took 0.0116 seconds
#
#
# Function initialize_composition took 0.0032 secondsFunction resize_final_resolution took 0.0000 seconds
# Function initialize_composition took 0.0055 secondsFunction blend_images took 0.0650 seconds
#
#
# Function warp took 0.0003 seconds
# Function warp_final_resolution took 0.0076 seconds
# Function create_final_panorama took 0.0090 secondsFunction blend_images took 0.0671 seconds
#
# Function crop took 0.0000 secondsStitching call count: 1
#
# Function crop_final_resolution took 0.0070 seconds
# Function create_final_panorama took 0.0077 secondsFunction resize_seam_masks took 0.0000 seconds
# Stitching call count: 1
#
# Function initialize_composition took 0.0010 seconds
# Function blend_images took 0.0822 seconds
# Function blend_images took 0.0894 seconds
# Function create_final_panorama took 0.0095 secondsFunction blend_images took 0.0803 seconds
#
# Stitching call count: 1
# Function create_final_panorama took 0.0150 seconds
# Stitching call count: 1Function create_final_panorama took 0.0112 seconds
#
# Stitching call count: 1
# Function blend_images took 0.0903 seconds
# Function blend_images took 0.0992 seconds
# Function create_final_panorama took 0.0152 seconds
# Function create_final_panorama took 0.0102 secondsStitching call count: 1
#
# Stitching call count: 1
# Function blend_images took 0.0883 seconds
# Function create_final_panorama took 0.0220 seconds
# Stitching call count: 1
# Estimated camera parameters
# Updated camera parameters with momentum
# (< cv2.detail.CameraParams 0x77b96b4b9300>, < cv2.detail.CameraParams 0x77b96b4b93f0>)
# Estimated camera parameters
# Estimated camera parametersUpdated camera parameters with momentum
#
# Updated camera parameters with momentum(< cv2.detail.CameraParams 0x77b96b4b9300>, < cv2.detail.CameraParams 0x77b96b4b93f0>)
#
# (< cv2.detail.CameraParams 0x77b96b4b7300>, < cv2.detail.CameraParams 0x77b96b4b73f0>)
# Estimated camera parameters
# Updated camera parameters with momentum
# Estimated camera parameters
# Estimated camera parametersUpdated camera parameters with momentum
#
# Updated camera parameters with momentum
# (< cv2.detail.CameraParams 0x77b96b4b9300>, < cv2.detail.CameraParams 0x77b96b4b93f0>)
# Estimated camera parameters(< cv2.detail.CameraParams 0x77b96b4b7300>, < cv2.detail.CameraParams 0x77b96b4b73f0>)
#
# Updated camera parameters with momentum
# (< cv2.detail.CameraParams 0x77b96b4b9300>, < cv2.detail.CameraParams 0x77b96b4b93f0>)Estimated camera parameters
# Updated camera parameters with momentum
#
# Error during stitching frame 8: Camera parameters adjusting failed.
# (< cv2.detail.CameraParams 0x77b96b4b7300>, < cv2.detail.CameraParams 0x77b96b4b73f0>)
# Stitching call count: 1
# Function resize_medium_resolution took 0.0003 seconds
# Stitching call count: 1
# Function resize_medium_resolution took 0.0002 secondsStitching call count: 1
#
# Function resize_medium_resolution took 0.0003 seconds
# Function find_features took 0.0240 seconds
# Function find_features took 0.0136 seconds
# Function find_features took 0.0160 seconds
# Stitching call count: 1
# Function resize_medium_resolution took 0.0003 seconds
# Function find_features took 0.0183 secondsFunction match_features took 0.0379 secondsFunction match_features took 0.0306 seconds
#
#
# Function match_features took 0.0341 secondsFunction subset took 0.0004 secondsFunction subset took 0.0003 seconds
#
#
# Function subset took 0.0002 secondsFunction estimate_camera_parameters took 0.0005 seconds
#
# Function estimate_camera_parameters took 0.0001 secondsEstimated camera parametersFunction estimate_camera_parameters took 0.0001 seconds
#
# Estimated camera parametersEstimated camera parameters
#
#
# Updated camera parameters with momentumUpdated camera parameters with momentumUpdated camera parameters with momentum
#
#
# Stitching call count: 1Function refine_camera_parameters took 0.0049 secondsFunction refine_camera_parameters took 0.0052 seconds
#
#
# Function resize_medium_resolution took 0.0002 seconds(< cv2.detail.CameraParams 0x77b97161cd50>, < cv2.detail.CameraParams 0x77b96b4b7030>)(< cv2.detail.CameraParams 0x77b97161cd50>, < cv2.detail.CameraParams 0x77b96b4b9030>)
#
# Function refine_camera_parameters took 0.0069 secondsFunction match_features took 0.0233 seconds
# Function perform_wave_correction took 0.0001 seconds
# Function perform_wave_correction took 0.0001 seconds
# Stitching call count: 1
# (< cv2.detail.CameraParams 0x77b97161cd50>, < cv2.detail.CameraParams 0x77b96b4b7030>)
# Function estimate_scale took 0.0000 seconds
# Function subset took 0.0002 secondsFunction estimate_scale took 0.0000 seconds
#
#
#
# Function estimate_camera_parameters took 0.0001 secondsFunction resize_medium_resolution took 0.0003 seconds
# Function perform_wave_correction took 0.0001 seconds
# Function resize_low_resolution took 0.0010 seconds
# Estimated camera parametersFunction resize_low_resolution took 0.0010 secondsFunction estimate_scale took 0.0000 seconds
# Stitching call count: 1
#
#
#
# Function warp took 0.0002 secondsUpdated camera parameters with momentum
# Function resize_medium_resolution took 0.0002 seconds
# Function resize_low_resolution took 0.0011 seconds
# Function warp took 0.0001 seconds
#
# Function warp took 0.0002 seconds
# Function warp_low_resolution took 0.0115 secondsFunction find_features took 0.0174 seconds
# Function find_features took 0.0138 seconds
# Function prepare_cropper took 0.0000 seconds
# Function warp_low_resolution took 0.0142 secondsFunction warp_low_resolution took 0.0117 seconds
#
# Function crop took 0.0000 secondsFunction prepare_cropper took 0.0000 seconds
#
# Function prepare_cropper took 0.0000 secondsFunction crop_low_resolution took 0.0013 seconds
#
# Function crop took 0.0000 seconds
# Function crop took 0.0000 secondsStitching call count: 1
#
#
# Function crop_low_resolution took 0.0012 secondsFunction resize_medium_resolution took 0.0003 secondsFunction crop_low_resolution took 0.0023 secondsFunction find_features took 0.0167 seconds
#
#
#
# Function find_seam_masks took 0.0059 seconds
# Function resize_final_resolution took 0.0000 secondsFunction find_seam_masks took 0.0050 seconds
# Function find_seam_masks took 0.0052 seconds
# Function warp took 0.0006 seconds
# Function resize_final_resolution took 0.0000 seconds
# Function resize_final_resolution took 0.0000 seconds
# Function warp_final_resolution took 0.0022 seconds
#
# Function warp took 0.0003 secondsFunction warp took 0.0003 secondsFunction crop took 0.0000 seconds
#
#
# Function warp_final_resolution took 0.0021 secondsFunction crop_final_resolution took 0.0017 secondsFunction warp_final_resolution took 0.0026 seconds
#
#
# Function crop took 0.0000 secondsFunction resize_seam_masks took 0.0000 secondsFunction crop took 0.0000 secondsFunction find_features took 0.0137 seconds
#
#
#
# Function crop_final_resolution took 0.0021 secondsFunction crop_final_resolution took 0.0017 secondsFunction match_features took 0.0229 seconds
#
#
# Function resize_seam_masks took 0.0000 secondsFunction initialize_composition took 0.0006 secondsFunction resize_seam_masks took 0.0000 secondsFunction subset took 0.0002 seconds
#
#
#
# Function estimate_camera_parameters took 0.0001 seconds
# Function initialize_composition took 0.0021 secondsEstimated camera parametersFunction initialize_composition took 0.0016 secondsFunction match_features took 0.0279 seconds
#
#
#
# Updated camera parameters with momentumFunction subset took 0.0002 seconds
#
# Function estimate_camera_parameters took 0.0001 seconds
# Function refine_camera_parameters took 0.0032 secondsEstimated camera parameters
#
# Function match_features took 0.0298 seconds(< cv2.detail.CameraParams 0x77b97161cd50>, < cv2.detail.CameraParams 0x77b96b4b9030>)Updated camera parameters with momentum
#
# Function subset took 0.0001 seconds
#
# Function perform_wave_correction took 0.0001 seconds
# Function estimate_camera_parameters took 0.0001 secondsFunction estimate_scale took 0.0000 seconds
# Estimated camera parameters
# Function refine_camera_parameters took 0.0047 seconds
# Function match_features took 0.0226 seconds
# Function resize_low_resolution took 0.0011 seconds
# Updated camera parameters with momentumFunction subset took 0.0002 seconds
#
#
# (< cv2.detail.CameraParams 0x77b97161cd50>, < cv2.detail.CameraParams 0x77b96b4b9030>)Function warp took 0.0001 secondsFunction estimate_camera_parameters took 0.0001 seconds
#
#
# Function perform_wave_correction took 0.0002 seconds
# Estimated camera parameters
#
# Updated camera parameters with momentumFunction estimate_scale took 0.0006 seconds
# Function resize_low_resolution took 0.0035 seconds
# Function warp took 0.0002 secondsFunction blend_images took 0.0422 secondsFunction warp_low_resolution took 0.0183 seconds
#
# Function refine_camera_parameters took 0.0123 seconds
#
# (< cv2.detail.CameraParams 0x77b97161cd50>, < cv2.detail.CameraParams 0x77b96b4b7030>)Function refine_camera_parameters took 0.0864 secondsFunction prepare_cropper took 0.0000 seconds
#
#
# Function create_final_panorama took 0.0062 seconds(< cv2.detail.CameraParams 0x77b97161cd50>, < cv2.detail.CameraParams 0x77b96b4b9030>)Function perform_wave_correction took 0.0001 seconds
# Function crop took 0.0000 secondsStitching call count: 2
#
#
# Function crop_low_resolution took 0.0021 seconds
# Function resize_medium_resolution took 0.0002 secondsFunction perform_wave_correction took 0.0001 secondsFunction blend_images took 0.0519 seconds
#
#
# Function warp_low_resolution took 0.0148 secondsFunction estimate_scale took 0.0000 seconds
#
# Function estimate_scale took 0.0000 secondsFunction blend_images took 0.0564 seconds
#
#
# Function create_final_panorama took 0.0051 secondsFunction prepare_cropper took 0.0000 secondsFunction resize_low_resolution took 0.0008 secondsFunction find_seam_masks took 0.0059 secondsFunction resize_low_resolution took 0.0013 seconds
#
# Function warp took 0.0002 seconds
#
# Function crop took 0.0000 seconds
# Function resize_final_resolution took 0.0000 seconds
#
#
# Function crop_low_resolution took 0.0019 secondsFunction create_final_panorama took 0.0059 seconds
# Function warp took 0.0002 seconds
# Function find_features took 0.0183 secondsStitching call count: 2Stitching call count: 2
#
# Function warp took 0.0003 seconds
# Function resize_medium_resolution took 0.0002 seconds
#
#
# Function resize_medium_resolution took 0.0003 secondsFunction warp_final_resolution took 0.0052 seconds
# Function crop took 0.0000 seconds
# Function find_seam_masks took 0.0065 secondsFunction warp_low_resolution took 0.0173 seconds
#
# Function resize_final_resolution took 0.0000 seconds
#
# Function crop_final_resolution took 0.0062 secondsFunction warp took 0.0003 secondsFunction warp_low_resolution took 0.0199 seconds
#
# Function prepare_cropper took 0.0000 seconds
# Function prepare_cropper took 0.0000 secondsFunction warp_final_resolution took 0.0034 secondsFunction resize_seam_masks took 0.0000 seconds
#
#
# Function crop took 0.0000 secondsFunction crop took 0.0000 seconds
#
# Function find_features took 0.0145 secondsFunction crop_low_resolution took 0.0013 seconds
#
# Function crop_low_resolution took 0.0038 seconds
# Function crop took 0.0000 secondsFunction initialize_composition took 0.0005 seconds
#
# Function find_features took 0.0145 secondsFunction match_features took 0.0209 secondsFunction crop_final_resolution took 0.0017 seconds
#
#
#
# Function resize_seam_masks took 0.0000 secondsFunction subset took 0.0001 seconds
#
# Used previous camera parameters
# Function initialize_composition took 0.0007 seconds
# Function find_seam_masks took 0.0050 secondsFunction find_seam_masks took 0.0068 seconds
#
# Function resize_final_resolution took 0.0000 secondsFunction resize_final_resolution took 0.0000 seconds
#
# Function warp took 0.0002 secondsFunction warp took 0.0002 seconds
#
# Function warp_final_resolution took 0.0028 secondsFunction warp_final_resolution took 0.0046 secondsFunction match_features took 0.0171 seconds
#
#
# Function crop took 0.0000 seconds
# Function subset took 0.0002 secondsFunction crop_final_resolution took 0.0024 secondsFunction crop took 0.0000 seconds
#
#
# Used previous camera parametersFunction crop_final_resolution took 0.0018 secondsFunction resize_seam_masks took 0.0000 seconds
#
#
# Function resize_seam_masks took 0.0000 secondsFunction refine_camera_parameters took 0.1027 seconds
#
# Function initialize_composition took 0.0011 seconds
# (< cv2.detail.CameraParams 0x77b97161cd50>, < cv2.detail.CameraParams 0x77b96b4b7030>)
# Function initialize_composition took 0.0006 secondsFunction match_features took 0.0287 seconds
# Function perform_wave_correction took 0.0001 seconds
#
# Function subset took 0.0001 secondsFunction estimate_scale took 0.0000 seconds
#
# Used previous camera parametersFunction resize_low_resolution took 0.0008 seconds
#
# Function warp took 0.0001 secondsFunction blend_images took 0.0399 seconds
#
# Function blend_images took 0.0470 seconds
# Function create_final_panorama took 0.0058 secondsFunction create_final_panorama took 0.0045 seconds
#
# Stitching call count: 2Stitching call count: 2
#
# Function resize_medium_resolution took 0.0002 seconds
# Function resize_medium_resolution took 0.0002 seconds
# Function warp_low_resolution took 0.0257 seconds
# Function prepare_cropper took 0.0000 seconds
# Function crop took 0.0000 seconds
# Function find_features took 0.0149 secondsFunction crop_low_resolution took 0.0023 secondsFunction blend_images took 0.0487 seconds
#
# Function blend_images took 0.0583 seconds
#
# Function find_features took 0.0177 seconds
# Function create_final_panorama took 0.0060 seconds
# Stitching call count: 2
# Function create_final_panorama took 0.0063 seconds
# Function resize_medium_resolution took 0.0004 secondsStitching call count: 2
#
# Function resize_medium_resolution took 0.0002 seconds
# Function find_seam_masks took 0.0145 seconds
# Function resize_final_resolution took 0.0000 seconds
# Function warp took 0.0003 seconds
# Function warp_final_resolution took 0.0017 seconds
# Function match_features took 0.0188 secondsFunction crop took 0.0000 seconds
#
# Function crop_final_resolution took 0.0008 secondsFunction match_features took 0.0165 secondsFunction subset took 0.0001 seconds
#
#
# Function resize_seam_masks took 0.0000 secondsUsed previous camera parametersFunction find_features took 0.0119 seconds
# Function subset took 0.0001 secondsFunction find_features took 0.0107 seconds
#
#
#
# Used previous camera parametersFunction refine_camera_parameters took 0.1091 seconds
#
# Function initialize_composition took 0.0027 seconds(< cv2.detail.CameraParams 0x77b96b4b7120>, < cv2.detail.CameraParams 0x77b96b4b7210>)
#
# Function perform_wave_correction took 0.0001 secondsFunction refine_camera_parameters took 0.0972 seconds
#
# Function estimate_scale took 0.0000 seconds(< cv2.detail.CameraParams 0x77b96b4b9120>, < cv2.detail.CameraParams 0x77b96b4b9210>)
#
# Function perform_wave_correction took 0.0001 secondsFunction resize_low_resolution took 0.0015 seconds
# Function estimate_scale took 0.0000 seconds
#
# Function warp took 0.0002 secondsFunction match_features took 0.0175 secondsFunction match_features took 0.0169 seconds
#
#
# Function resize_low_resolution took 0.0008 seconds
# Function subset took 0.0002 secondsFunction subset took 0.0001 secondsFunction warp took 0.0002 seconds
#
#
# Used previous camera parametersUsed previous camera parameters
#
# Function warp_low_resolution took 0.0159 seconds
# Function prepare_cropper took 0.0000 seconds
# Function refine_camera_parameters took 0.1066 secondsFunction crop took 0.0000 secondsFunction warp_low_resolution took 0.0148 seconds
#
#
# (< cv2.detail.CameraParams 0x77b96b4b7120>, < cv2.detail.CameraParams 0x77b96b4b7210>)Function crop_low_resolution took 0.0017 seconds
#
# Function prepare_cropper took 0.0000 seconds
# Function perform_wave_correction took 0.0001 seconds
# Function estimate_scale took 0.0000 secondsFunction crop took 0.0000 seconds
#
# Function crop_low_resolution took 0.0012 seconds
# Function resize_low_resolution took 0.0013 seconds
# Function find_seam_masks took 0.0073 seconds
# Function warp took 0.0002 secondsFunction resize_final_resolution took 0.0000 seconds
#
# Function warp took 0.0002 seconds
# Function warp_final_resolution took 0.0029 secondsFunction find_seam_masks took 0.0085 seconds
# Function crop took 0.0000 seconds
# Function resize_final_resolution took 0.0000 seconds
#
# Function crop_final_resolution took 0.0021 secondsFunction warp took 0.0002 seconds
# Function warp_final_resolution took 0.0025 seconds
#
# Function resize_seam_masks took 0.0000 secondsFunction warp_low_resolution took 0.0153 seconds
# Function crop took 0.0000 seconds
#
# Function initialize_composition took 0.0006 secondsFunction prepare_cropper took 0.0000 secondsFunction crop_final_resolution took 0.0019 seconds
#
#
# Function crop took 0.0000 secondsFunction resize_seam_masks took 0.0000 seconds
#
# Function crop_low_resolution took 0.0035 seconds
# Function initialize_composition took 0.0007 seconds
# Function find_seam_masks took 0.0062 seconds
# Function resize_final_resolution took 0.0000 seconds
# Function warp took 0.0003 secondsFunction blend_images took 0.0930 seconds
# Function refine_camera_parameters took 0.0985 seconds
#
# Function warp_final_resolution took 0.0060 secondsFunction refine_camera_parameters took 0.0983 seconds(< cv2.detail.CameraParams 0x77b96b4b9120>, < cv2.detail.CameraParams 0x77b96b4b9210>)
#
# Function crop took 0.0000 seconds
# Function perform_wave_correction took 0.0001 seconds(< cv2.detail.CameraParams 0x77b96b4b9120>, < cv2.detail.CameraParams 0x77b96b4b9210>)
#
#
# Function crop_final_resolution took 0.0056 secondsFunction estimate_scale took 0.0000 secondsFunction perform_wave_correction took 0.0001 seconds
#
# Function resize_seam_masks took 0.0000 seconds
# Function estimate_scale took 0.0000 seconds
# Function create_final_panorama took 0.0129 secondsFunction resize_low_resolution took 0.0008 seconds
#
# Function initialize_composition took 0.0008 seconds
# Function warp took 0.0002 secondsStitching call count: 2
#
#
# Function resize_low_resolution took 0.0012 secondsFunction resize_medium_resolution took 0.0002 seconds
#
# Function warp took 0.0001 seconds
# Function warp_low_resolution took 0.0144 seconds
# Function prepare_cropper took 0.0000 seconds
# Function refine_camera_parameters took 0.1014 secondsFunction crop took 0.0000 seconds
#
# Function crop_low_resolution took 0.0017 seconds
# (< cv2.detail.CameraParams 0x77b96b4b9120>, < cv2.detail.CameraParams 0x77b96b4b9210>)
# Function perform_wave_correction took 0.0001 secondsFunction find_features took 0.0141 seconds
# Function estimate_scale took 0.0000 seconds
#
# Function warp_low_resolution took 0.0204 seconds
# Function refine_camera_parameters took 0.1178 secondsFunction prepare_cropper took 0.0000 secondsFunction blend_images took 0.0719 secondsFunction blend_images took 0.0790 seconds
# Function crop took 0.0000 seconds
# Function resize_low_resolution took 0.0016 seconds
# (< cv2.detail.CameraParams 0x77b96b4b7120>, < cv2.detail.CameraParams 0x77b96b4b7210>)
# Function crop_low_resolution took 0.0017 seconds
#
#
#
# Function warp took 0.0002 secondsFunction find_seam_masks took 0.0129 secondsFunction perform_wave_correction took 0.0001 seconds
#
#
# Function resize_final_resolution took 0.0000 secondsFunction estimate_scale took 0.0000 seconds
# Function warp took 0.0004 seconds
# Function create_final_panorama took 0.0075 seconds
# Function create_final_panorama took 0.0099 secondsFunction resize_low_resolution took 0.0011 secondsFunction find_seam_masks took 0.0092 seconds
# Function warp_final_resolution took 0.0051 seconds
#
# Stitching call count: 1
#
# Stitching call count: 1
# Function blend_images took 0.0483 secondsFunction warp took 0.0002 secondsFunction crop took 0.0000 seconds
#
# Function match_features took 0.0261 secondsFunction resize_final_resolution took 0.0000 seconds
#
# Function crop_final_resolution took 0.0055 seconds
# Function warp_low_resolution took 0.0172 seconds
#
# Function warp took 0.0003 seconds
# Function create_final_panorama took 0.0068 seconds
# Function subset took 0.0002 secondsFunction resize_seam_masks took 0.0000 secondsFunction prepare_cropper took 0.0000 seconds
#
# Function warp_final_resolution took 0.0036 seconds
#
#
# Function crop took 0.0000 seconds
# Function initialize_composition took 0.0011 secondsUsed previous camera parametersFunction crop took 0.0000 seconds
# Stitching call count: 1Function crop_low_resolution took 0.0015 seconds
#
#
#
# Function warp_low_resolution took 0.0210 secondsFunction crop_final_resolution took 0.0049 seconds
# Function prepare_cropper took 0.0000 seconds
# Function find_seam_masks took 0.0055 secondsFunction crop took 0.0000 seconds
#
# Function resize_seam_masks took 0.0000 seconds
# Function crop_low_resolution took 0.0030 seconds
#
# Function resize_final_resolution took 0.0000 secondsFunction initialize_composition took 0.0010 seconds
#
# Function warp took 0.0003 seconds
# Function warp_final_resolution took 0.0025 seconds
# Function crop took 0.0000 seconds
# Function crop_final_resolution took 0.0017 seconds
# Function resize_seam_masks took 0.0000 secondsFunction find_seam_masks took 0.0092 seconds
#
# Function initialize_composition took 0.0007 secondsFunction resize_final_resolution took 0.0000 seconds
#
# Function warp took 0.0004 seconds
# Function warp_final_resolution took 0.0049 seconds
# Function crop took 0.0000 seconds
# Function crop_final_resolution took 0.0042 seconds
# Function resize_seam_masks took 0.0000 seconds
# Function initialize_composition took 0.0008 seconds
# Function blend_images took 0.0487 secondsFunction blend_images took 0.0686 seconds
#
# Function create_final_panorama took 0.0066 seconds
# Stitching call count: 1Function create_final_panorama took 0.0120 seconds
#
# Function blend_images took 0.0703 seconds
# Stitching call count: 1
# Function create_final_panorama took 0.0132 seconds
# Stitching call count: 1
# Function refine_camera_parameters took 0.1367 seconds
# (< cv2.detail.CameraParams 0x77b96b4b7120>, < cv2.detail.CameraParams 0x77b96b4b7210>)
# Function blend_images took 0.0983 secondsFunction perform_wave_correction took 0.0001 seconds
#
# Function estimate_scale took 0.0000 seconds
# Function resize_low_resolution took 0.0015 secondsFunction create_final_panorama took 0.0088 seconds
#
# Stitching call count: 1Function warp took 0.0002 seconds
#
# Function warp_low_resolution took 0.0190 seconds
# Function prepare_cropper took 0.0000 seconds
# Function crop took 0.0000 seconds
# Function crop_low_resolution took 0.0031 seconds
# Function find_seam_masks took 0.0145 seconds
# Function resize_final_resolution took 0.0000 seconds
# Function warp took 0.0004 seconds
# Function warp_final_resolution took 0.0086 seconds
# Function crop took 0.0000 seconds
# Function crop_final_resolution took 0.0074 seconds
# Function resize_seam_masks took 0.0000 seconds
# Estimated camera parametersFunction initialize_composition took 0.0006 seconds
#
# Updated camera parameters with momentum
# Estimated camera parameters
# Updated camera parameters with momentumError during stitching frame 33: No match exceeds the given confidence threshold.
#                                  Do your images have enough overlap and common
#                                  features? If yes, you might want to lower the
#                                  'confidence_threshold' or try another
#                                  'detector'.
#
# (< cv2.detail.CameraParams 0x77b96b4b7300>, < cv2.detail.CameraParams 0x77b96b4b73f0>)
# (< cv2.detail.CameraParams 0x77b96b4b7300>, < cv2.detail.CameraParams 0x77b96b4b73f0>)
# Function blend_images took 0.0484 seconds
# Function create_final_panorama took 0.0111 seconds
# Stitching call count: 1
# Estimated camera parameters
# Updated camera parameters with momentum
# (< cv2.detail.CameraParams 0x77b96b4b9300>, < cv2.detail.CameraParams 0x77b96b4b93f0>)
# Estimated camera parameters
# Updated camera parameters with momentum
# Estimated camera parameters
# Updated camera parameters with momentum
# (< cv2.detail.CameraParams 0x77b96b4b9300>, < cv2.detail.CameraParams 0x77b96b4b93f0>)
# Estimated camera parameters
# Updated camera parameters with momentum
# (< cv2.detail.CameraParams 0x77b96b4b7300>, < cv2.detail.CameraParams 0x77b96b4b73f0>)
# Error during stitching frame 49: Camera parameters adjusting failed.
# Stitching call count: 1
# Function resize_medium_resolution took 0.0003 seconds
# Function find_features took 0.0138 seconds
# Error during stitching frame 25: No match exceeds the given confidence threshold.
#                                  Do your images have enough overlap and common
#                                  features? If yes, you might want to lower the
#                                  'confidence_threshold' or try another
#                                  'detector'.
# Stitching call count: 1
# Stitching call count: 1Function resize_medium_resolution took 0.0004 seconds
# Function match_features took 0.0286 secondsFunction resize_medium_resolution took 0.0004 seconds
#
# Function subset took 0.0002 seconds
#
# Function estimate_camera_parameters took 0.0002 seconds
# Estimated camera parameters
# Updated camera parameters with momentum
# Function find_features took 0.0159 secondsFunction find_features took 0.0174 secondsFunction refine_camera_parameters took 0.0022 seconds
#
#
# (< cv2.detail.CameraParams 0x77b97161cd50>, < cv2.detail.CameraParams 0x77b96b4b9030>)
# Function perform_wave_correction took 0.0001 seconds
# Function estimate_scale took 0.0000 seconds
# Function resize_low_resolution took 0.0011 seconds
# Function warp took 0.0002 seconds
# Function match_features took 0.0252 seconds
# Function subset took 0.0002 secondsFunction warp_low_resolution took 0.0163 seconds
#
# Function estimate_camera_parameters took 0.0002 secondsFunction prepare_cropper took 0.0000 seconds
#
# Function match_features took 0.0388 secondsEstimated camera parametersFunction crop took 0.0000 seconds
#
# Function subset took 0.0002 seconds
#
# Function estimate_camera_parameters took 0.0001 secondsFunction crop_low_resolution took 0.0063 secondsUpdated camera parameters with momentum
#
#
# Estimated camera parameters
# Function refine_camera_parameters took 0.0017 seconds
# Updated camera parameters with momentumFunction find_seam_masks took 0.0061 seconds(< cv2.detail.CameraParams 0x77b97161cb70>, < cv2.detail.CameraParams 0x77b96b4b7030>)
#
# Stitching call count: 1
# Function perform_wave_correction took 0.0002 secondsStitching call count: 1Function refine_camera_parameters took 0.0026 secondsFunction resize_final_resolution took 0.0000 seconds
#
#
#
#
# (< cv2.detail.CameraParams 0x77b97161cb70>, < cv2.detail.CameraParams 0x77b96b4b7030>)Function resize_medium_resolution took 0.0003 secondsFunction resize_medium_resolution took 0.0004 secondsFunction estimate_scale took 0.0000 secondsStitching call count: 1Function warp took 0.0004 seconds
#
#
#
#
#
# Function perform_wave_correction took 0.0003 secondsFunction warp_final_resolution took 0.0038 secondsFunction resize_medium_resolution took 0.0003 seconds
# Function resize_low_resolution took 0.0014 seconds
#
# Function estimate_scale took 0.0000 seconds
# Function crop took 0.0000 seconds
#
# Function warp took 0.0002 secondsFunction crop_final_resolution took 0.0038 seconds
# Function resize_low_resolution took 0.0015 seconds
# Function resize_seam_masks took 0.0000 seconds
#
# Function warp took 0.0002 secondsFunction initialize_composition took 0.0006 seconds
# Function find_features took 0.0203 seconds
# Function find_features took 0.0200 seconds
#
# Stitching call count: 1
# Function find_features took 0.0184 seconds
# Function warp_low_resolution took 0.0195 seconds
# Function resize_medium_resolution took 0.0002 secondsFunction warp_low_resolution took 0.0151 secondsFunction prepare_cropper took 0.0000 seconds
#
#
# Function crop took 0.0000 secondsFunction prepare_cropper took 0.0000 seconds
#
# Function crop_low_resolution took 0.0041 secondsFunction crop took 0.0000 seconds
#
# Function crop_low_resolution took 0.0031 seconds
# Function find_seam_masks took 0.0078 seconds
# Function find_features took 0.0166 seconds
# Stitching call count: 1Function resize_final_resolution took 0.0000 seconds
#
# Function resize_medium_resolution took 0.0002 seconds
# Function warp took 0.0003 secondsFunction find_seam_masks took 0.0101 secondsFunction match_features took 0.0348 secondsFunction subset took 0.0002 seconds
#
#
# Function warp_final_resolution took 0.0079 secondsFunction match_features took 0.0388 secondsFunction resize_final_resolution took 0.0000 seconds
#
#
# Function match_features took 0.0414 secondsFunction estimate_camera_parameters took 0.0002 secondsFunction crop took 0.0000 seconds
#
#
#
# Function subset took 0.0002 secondsFunction warp took 0.0003 seconds
# Function blend_images took 0.0550 secondsFunction subset took 0.0001 seconds
#
# Function warp_final_resolution took 0.0060 secondsFunction find_features took 0.0235 secondsEstimated camera parameters
# Function estimate_camera_parameters took 0.0001 secondsFunction estimate_camera_parameters took 0.0002 seconds
# Function crop_final_resolution took 0.0067 secondsUpdated camera parameters with momentumFunction match_features took 0.0329 seconds
#
#
#
# Function resize_seam_masks took 0.0000 seconds
# Function crop took 0.0000 seconds
# Estimated camera parameters
#
#
#
# Estimated camera parametersUpdated camera parameters with momentum
# Function crop_final_resolution took 0.0056 secondsFunction subset took 0.0004 secondsFunction initialize_composition took 0.0013 seconds
#
#
# Function create_final_panorama took 0.0100 seconds
# Updated camera parameters with momentumFunction refine_camera_parameters took 0.0054 seconds
# Function resize_seam_masks took 0.0000 seconds
#
# ...
#
#
# Function blend_images took 0.0666 secondsStitching call count: 1Estimated camera parameters
#
#
# Updated camera parameters with momentum
# (< cv2.detail.CameraParams 0x77b96b4c1300>, < cv2.detail.CameraParams 0x77b96b4c13f0>)
# Function create_final_panorama took 0.0065 secondsFunction find_features took 0.0208 seconds
#
# Stitching call count: 1Function warp_low_resolution took 0.0152 seconds
#
# Function prepare_cropper took 0.0000 seconds
# Function refine_camera_parameters took 0.0139 seconds
# (< cv2.detail.CameraParams 0x77b97161cd50>, < cv2.detail.CameraParams 0x77b96b4c2030>)
# Function crop took 0.0000 secondsFunction perform_wave_correction took 0.0001 seconds
#
# Function estimate_scale took 0.0000 secondsFunction crop_low_resolution took 0.0050 seconds
#
# Function resize_low_resolution took 0.0011 seconds
# Function warp took 0.0002 secondsFunction find_seam_masks took 0.0084 seconds
#
# Function resize_final_resolution took 0.0000 seconds
# Function warp took 0.0002 seconds
# Function warp_final_resolution took 0.0017 seconds
# Function match_features took 0.0358 seconds
# Function crop took 0.0000 secondsFunction subset took 0.0002 seconds
# Function crop_final_resolution took 0.0073 secondsFunction warp_low_resolution took 0.0196 seconds
#
#
# Function estimate_camera_parameters took 0.0001 secondsFunction resize_seam_masks took 0.0000 seconds
#
# Estimated camera parametersFunction prepare_cropper took 0.0000 seconds
# Function initialize_composition took 0.0009 seconds
#
# Function crop took 0.0000 seconds
# Updated camera parameters with momentum
# Function crop_low_resolution took 0.0029 seconds
# Function find_seam_masks took 0.0085 seconds
# Function resize_final_resolution took 0.0000 seconds
# Function warp took 0.0011 seconds
# Function warp_final_resolution took 0.0086 seconds
# Function crop took 0.0000 seconds
# Function crop_final_resolution took 0.0052 seconds
# Function resize_seam_masks took 0.0000 seconds
# Estimated camera parametersFunction initialize_composition took 0.0005 seconds
#
# Updated camera parameters with momentum
# (< cv2.detail.CameraParams 0x77b96b4c1300>, < cv2.detail.CameraParams 0x77b96b4c13f0>)
#
# Function blend_images took 0.0885 secondsFunction create_final_panorama took 0.0089 seconds
# Stitching call count: 1Function refine_camera_parameters took 0.1105 secondsFunction blend_images took 0.0419 seconds
#
#
# (< cv2.detail.CameraParams 0x77b97161cb70>, < cv2.detail.CameraParams 0x77b96b4c5030>)
# Function perform_wave_correction took 0.0001 seconds
# Function estimate_scale took 0.0000 secondsFunction create_final_panorama took 0.0110 seconds
#
# Function resize_low_resolution took 0.0011 secondsStitching call count: 2Function resize_medium_resolution took 0.0002 seconds
#
#
# Function warp took 0.0002 seconds
# Estimated camera parameters
# Function find_features took 0.0169 seconds
# Updated camera parameters with momentumFunction warp_low_resolution took 0.0233 seconds
#
# Function prepare_cropper took 0.0000 seconds
# Function crop took 0.0000 seconds
# (< cv2.detail.CameraParams 0x77b96b4c5300>, < cv2.detail.CameraParams 0x77b96b4c53f0>)
# Function crop_low_resolution took 0.0078 seconds
# Function find_seam_masks took 0.0088 seconds
# Function resize_final_resolution took 0.0000 seconds
# Function warp took 0.0003 seconds
# Function match_features took 0.0332 secondsFunction warp_final_resolution took 0.0027 seconds
#
# Function subset took 0.0003 seconds
# Function crop took 0.0000 seconds
# Used previous camera parameters
# Function crop_final_resolution took 0.0015 seconds
# Function resize_seam_masks took 0.0000 seconds
# Estimated camera parameters
# Function initialize_composition took 0.0011 secondsUpdated camera parameters with momentum
#
# (< cv2.detail.CameraParams 0x77b96b4c2300>, < cv2.detail.CameraParams 0x77b96b4c23f0>)
# Function blend_images took 0.0609 seconds
# Function create_final_panorama took 0.0072 seconds
# Stitching call count: 2
# Function resize_medium_resolution took 0.0002 seconds
# Function find_features took 0.0112 seconds
# Function refine_camera_parameters took 0.1065 seconds
# (< cv2.detail.CameraParams 0x77b96b4c2120>, < cv2.detail.CameraParams 0x77b96b4c2210>)
# Function perform_wave_correction took 0.0001 seconds
# Function estimate_scale took 0.0000 seconds
# Function resize_low_resolution took 0.0007 seconds
# Function warp took 0.0001 seconds
# Function match_features took 0.0219 seconds
# Function subset took 0.0002 seconds
# Used previous camera parameters
# Function warp_low_resolution took 0.0112 seconds
# Function prepare_cropper took 0.0000 seconds
# Function crop took 0.0000 seconds
# Function crop_low_resolution took 0.0062 seconds
# Function find_seam_masks took 0.0077 seconds
#
# Function resize_final_resolution took 0.0000 secondsFunction warp took 0.0003 seconds
# Function warp_final_resolution took 0.0025 seconds
# Function crop took 0.0000 seconds
# Estimated camera parameters
# Function crop_final_resolution took 0.0096 secondsUpdated camera parameters with momentum
# Function resize_seam_masks took 0.0000 seconds
#
# Function initialize_composition took 0.0008 seconds
# Function refine_camera_parameters took 0.0962 seconds
#
# (< cv2.detail.CameraParams 0x77b96b4c5120>, < cv2.detail.CameraParams 0x77b96b4c5210>)Function perform_wave_correction took 0.0001 seconds
# Function estimate_scale took 0.0000 seconds
# Function resize_low_resolution took 0.0013 seconds
# Function blend_images took 0.0508 secondsFunction warp took 0.0002 seconds
#
# Stitching call count: 1
# Function create_final_panorama took 0.0067 secondsFunction resize_medium_resolution took 0.0004 seconds
#
# Stitching call count: 1Function warp_low_resolution took 0.0135 seconds
#
# Function prepare_cropper took 0.0000 seconds
# Function crop took 0.0000 seconds
# Function crop_low_resolution took 0.0010 seconds
# Function find_seam_masks took 0.0068 secondsFunction find_features took 0.0134 seconds
#
# Function resize_final_resolution took 0.0000 seconds
# Function warp took 0.0003 seconds
# Function warp_final_resolution took 0.0012 seconds
# Function crop took 0.0000 seconds
# Function crop_final_resolution took 0.0021 seconds(< cv2.detail.CameraParams 0x77b96b4c1300>, < cv2.detail.CameraParams 0x77b96b4c13f0>)
#
# Function resize_seam_masks took 0.0000 seconds
# Function initialize_composition took 0.0006 seconds
# Function match_features took 0.0326 seconds
# Function subset took 0.0002 seconds
# Function estimate_camera_parameters took 0.0001 seconds
# Estimated camera parameters
# Updated camera parameters with momentum
# Function blend_images took 0.0431 seconds
# Function create_final_panorama took 0.0072 seconds
# Stitching call count: 1Function refine_camera_parameters took 0.0202 seconds
#
# (< cv2.detail.CameraParams 0x77b97161cd50>, < cv2.detail.CameraParams 0x77b96b4c2030>)
# Function perform_wave_correction took 0.0001 seconds
# Function estimate_scale took 0.0000 seconds
# Function resize_low_resolution took 0.0007 seconds
# Function warp took 0.0001 seconds
# Function warp_low_resolution took 0.0114 seconds
# Function prepare_cropper took 0.0000 seconds
# Function crop took 0.0000 seconds
# Function crop_low_resolution took 0.0008 seconds
# Function find_seam_masks took 0.0074 seconds
# Function resize_final_resolution took 0.0000 seconds
# Function warp took 0.0003 seconds
# Function warp_final_resolution took 0.0014 seconds
# Function crop took 0.0000 seconds
# Function crop_final_resolution took 0.0009 seconds
# Function resize_seam_masks took 0.0000 seconds
# Function initialize_composition took 0.0012 seconds
# Function blend_images took 0.0540 seconds
# Estimated camera parameters
# Updated camera parameters with momentumFunction create_final_panorama took 0.0064 seconds
#
# Stitching call count: 2
# Function resize_medium_resolution took 0.0002 seconds
# (< cv2.detail.CameraParams 0x77b96b4c2300>, < cv2.detail.CameraParams 0x77b96b4c23f0>)
# Function find_features took 0.0110 seconds
# Stitching call count: 1
# Function resize_medium_resolution took 0.0002 seconds
# Function match_features took 0.0243 seconds
# Function subset took 0.0002 seconds
# Used previous camera parametersFunction find_features took 0.0130 seconds
#
# Function match_features took 0.0229 seconds
# Function subset took 0.0002 seconds
# Function estimate_camera_parameters took 0.0001 seconds
# Estimated camera parametersEstimated camera parameters
#
# Updated camera parameters with momentumUpdated camera parameters with momentum
#
# (< cv2.detail.CameraParams 0x77b96b4c5300>, < cv2.detail.CameraParams 0x77b96b4c53f0>)
# Function refine_camera_parameters took 0.0103 seconds
# (< cv2.detail.CameraParams 0x77b97161cb70>, < cv2.detail.CameraParams 0x77b96b4c1030>)
# Function perform_wave_correction took 0.0001 seconds
# Function estimate_scale took 0.0000 seconds
# Function resize_low_resolution took 0.0010 seconds
# Function warp took 0.0002 seconds
# Function warp_low_resolution took 0.0101 seconds
# Function prepare_cropper took 0.0000 seconds
# Function crop took 0.0000 seconds
# Function crop_low_resolution took 0.0008 seconds
# Function find_seam_masks took 0.0040 seconds
# Function resize_final_resolution took 0.0000 seconds
# Function warp took 0.0002 seconds
# Function warp_final_resolution took 0.0016 seconds
# Function crop took 0.0000 seconds
# Function crop_final_resolution took 0.0014 seconds
# Function resize_seam_masks took 0.0000 seconds
# Function initialize_composition took 0.0007 seconds
# Function refine_camera_parameters took 0.0834 seconds
# (< cv2.detail.CameraParams 0x77b96b4c2120>, < cv2.detail.CameraParams 0x77b96b4c2210>)
# Function perform_wave_correction took 0.0001 seconds
# Function estimate_scale took 0.0000 seconds
# Function resize_low_resolution took 0.0020 secondsFunction warp took 0.0002 seconds
#
# Function blend_images took 0.0419 seconds
# Function warp_low_resolution took 0.0194 seconds
# Function prepare_cropper took 0.0000 seconds
# Function crop took 0.0000 seconds
# Function create_final_panorama took 0.0049 secondsFunction crop_low_resolution took 0.0013 seconds
#
# Stitching call count: 2
# Function resize_medium_resolution took 0.0003 seconds
# Function find_seam_masks took 0.0058 seconds
# Function resize_final_resolution took 0.0000 seconds
# Function warp took 0.0002 seconds
# Function warp_final_resolution took 0.0009 seconds
# Function crop took 0.0000 secondsFunction find_features took 0.0084 seconds
#
# Function crop_final_resolution took 0.0010 seconds
# Function resize_seam_masks took 0.0000 seconds
# Function initialize_composition took 0.0013 seconds
# Function match_features took 0.0236 seconds
# Function subset took 0.0001 seconds
# Used previous camera parameters
# Function blend_images took 0.0346 seconds
# Function create_final_panorama took 0.0062 secondsStitching call count: 1
#
# Function refine_camera_parameters took 0.0814 seconds
# (< cv2.detail.CameraParams 0x77b96b4c1120>, < cv2.detail.CameraParams 0x77b96b4c1210>)
# Function perform_wave_correction took 0.0001 seconds
# Function estimate_scale took 0.0000 seconds
# Function resize_low_resolution took 0.0007 seconds
# Function warp took 0.0001 seconds
# Function warp_low_resolution took 0.0124 seconds
# Function prepare_cropper took 0.0000 seconds
# Function crop took 0.0000 seconds
# Function crop_low_resolution took 0.0017 seconds
# Function find_seam_masks took 0.0065 seconds
# Function resize_final_resolution took 0.0000 seconds
# Function warp took 0.0004 seconds
# Function warp_final_resolution took 0.0018 seconds
# Function crop took 0.0000 seconds
# Function crop_final_resolution took 0.0008 seconds
# Function resize_seam_masks took 0.0000 seconds
# Function initialize_composition took 0.0012 seconds
# Function blend_images took 0.0362 seconds
# Function create_final_panorama took 0.0051 seconds
# Stitching call count: 1
# Estimated camera parameters
# Updated camera parameters with momentum
# (< cv2.detail.CameraParams 0x77b96b4c2300>, < cv2.detail.CameraParams 0x77b96b4c23f0>)
# Estimated camera parameters
#
# Updated camera parameters with momentum(< cv2.detail.CameraParams 0x77b96b4c1300>, < cv2.detail.CameraParams 0x77b96b4c13f0>)
# Saved panorama 0
# Saved panorama 1
# Saved panorama 3
# Saved panorama 4
# Saved panorama 5
# Saved panorama 6
# Saved panorama 7
# Saved panorama 9
# Saved panorama 10
# Saved panorama 11
# Saved panorama 12
# Saved panorama 13
# Saved panorama 14
# Saved panorama 16
# Saved panorama 17
# Saved panorama 18
# Saved panorama 19
# Saved panorama 20
# Saved panorama 21
# Saved panorama 22
# Saved panorama 23
# Saved panorama 24
# Saved panorama 26
# Saved panorama 27
# Saved panorama 28
# Saved panorama 30
# Saved panorama 32
# Saved panorama 34
# Saved panorama 35
# Saved panorama 36
# Saved panorama 37
# Saved panorama 38
# Saved panorama 39
# Saved panorama 40
# Saved panorama 41
# Saved panorama 42
# Saved panorama 43
# Saved panorama 44
# Saved panorama 48
# Saved panorama 50
# Saved panorama 51
# Saved panorama 52
# Saved panorama 54
# Saved panorama 55
# Saved panorama 56
# Saved panorama 57
# Saved panorama 58
# Saved panorama 59
# Saved panorama 60
# Saved panorama 61
# Saved panorama 62
# Saved panorama 65
# Saved panorama 66
# Saved panorama 68
# Saved panorama 69
# Saved panorama 70
# Saved panorama 71
# Saved panorama 72
# Saved panorama 73
# Saved panorama 75
# Saved panorama 77
# Saved panorama 78
# Saved panorama 79
# Saved panorama 80
# Saved panorama 82
# Saved panorama 83
# Saved panorama 84
# Saved panorama 86
# Saved panorama 87
# Saved panorama 89
# Saved panorama 90
# Saved panorama 91
# Saved panorama 92
# Saved panorama 93
# Saved panorama 94
# Saved panorama 95
# Saved panorama 96
# Saved panorama 97
# Saved panorama 98
# Saved panorama 99
# Saved panorama 100
# Saved panorama 101
# Saved panorama 102
# Saved panorama 103
# Saved panorama 104
# Saved panorama 105
# Saved panorama 106
# Saved panorama 107
# Saved panorama 108
# Saved panorama 109
# Saved panorama 110
# Saved panorama 111
# Saved panorama 112
# Saved panorama 113
# Saved panorama 114
# Saved panorama 115
# Saved panorama 116
# Saved panorama 117
# Saved panorama 118
# Saved panorama 119
# Saved panorama 120
# Saved panorama 121
# Saved panorama 123
# Saved panorama 124
# Saved panorama 126
# Saved panorama 127
# Saved panorama 129
# Saved panorama 130
# Saved panorama 131
# Saved panorama 133
# Saved panorama 134
# Saved panorama 135
# Saved panorama 136
# Saved panorama 137
# Saved panorama 138
# Saved panorama 139
# Saved panorama 140
# Saved panorama 141
# Saved panorama 142
# Saved panorama 144
# Saved panorama 145
# Saved panorama 146
# Saved panorama 147
# Saved panorama 148
# Saved panorama 150
# Saved panorama 151
# Saved panorama 152
# Saved panorama 153
# Saved panorama 154
# Saved panorama 155
# Saved panorama 156
# Saved panorama 158
# Saved panorama 159
# Saved panorama 160
# Saved panorama 163
# Saved panorama 164
# Saved panorama 165
# Saved panorama 166
# Saved panorama 167
# Saved panorama 168
# Saved panorama 169
# Saved panorama 170
# Saved panorama 171
# Saved panorama 172
# Saved panorama 173
# Saved panorama 174
# Saved panorama 175
# Saved panorama 176
# Saved panorama 177
# Saved panorama 178
# Saved panorama 179
# Saved panorama 180
# Saved panorama 181
# Saved panorama 183
# Saved panorama 184
# Saved panorama 185
# Saved panorama 186
# Saved panorama 187
# Saved panorama 188
# Saved panorama 189
# Saved panorama 190
# Saved panorama 191
# Saved panorama 192
# Saved panorama 193
# Saved panorama 194
# Saved panorama 195
# Saved panorama 196
# Saved panorama 197
# Saved panorama 199
# Saved panorama 200
# Saved panorama 201
# Saved panorama 202
# Saved panorama 204
# Saved panorama 206
# Saved panorama 207
# Saved panorama 208
# Saved panorama 209
# Saved panorama 210
# Saved panorama 211
# Saved panorama 212
# Saved panorama 213
# Saved panorama 214
# Saved panorama 215
# Saved panorama 217
# Saved panorama 218
# Saved panorama 219
# Saved panorama 220
# Saved panorama 221
# Saved panorama 222
# Saved panorama 223
# Saved panorama 224
# Saved panorama 225
# Saved panorama 227
# Saved panorama 228
# Saved panorama 229
# Saved panorama 230
# Saved panorama 231
# Saved panorama 232
# Saved panorama 235
# Saved panorama 236
# Saved panorama 237
# Saved panorama 238
# Saved panorama 239
# Saved panorama 240
# Saved panorama 241
# Saved panorama 242
# Saved panorama 243
# Saved panorama 244
# Saved panorama 246
# Saved panorama 247
# Saved panorama 248
# Saved panorama 249
# Saved panorama 253
# Saved panorama 254
# Saved panorama 255
# Total stitching time with 8 processes: 42.4320 seconds
# fps : 6.033

# %%
import os
import cv2

# 定义包含图像的文件夹
image_folder = './output'  # 更新为正确的路径

# 定义输出视频路径
video_path = 'output_video.mp4'  # 更新为所需的输出路径

# 获取图像列表
images = [img for img in os.listdir(image_folder) if img.endswith(".jpg")]
images.sort()  # 确保图像是排序的

# 找到最大尺寸
max_width, max_height = 0, 0
for image in images:
    img_path = os.path.join(image_folder, image)
    frame = cv2.imread(img_path)
    if frame is not None:
        height, width, layers = frame.shape
        if width > max_width:
            max_width = width
        if height > max_height:
            max_height = height

# 定义帧率
fps = 30  # 根据需要调整帧率

# 定义视频编解码器并创建 VideoWriter 对象
fourcc = cv2.VideoWriter_fourcc(*'XVID')  # 定义编解码器
video = cv2.VideoWriter(video_path, fourcc, fps, (max_width, max_height), True)  # 指定帧率和是否彩色

# 将图像写入视频
for image in images:
    img_path = os.path.join(image_folder, image)
    frame = cv2.imread(img_path)
    if frame is not None:
        resized_frame = cv2.resize(frame, (max_width, max_height))
        video.write(resized_frame)

# 释放视频写入对象
video.release()

print("视频创建成功。")
# Out:
# OpenCV: FFMPEG: tag 0x44495658/'XVID' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 视频创建成功。
